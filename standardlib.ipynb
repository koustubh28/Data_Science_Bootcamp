# %%
import os
print(os.getcwd())
# Out:
# d:\ds_bootcamp\python program

# %%
os.mkdir('testdir')

# %% [markdown]
# High Level Operations on Files

# %%
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'
