# %% [markdown]
# Logging with multiple Loggers

# %%
import logging

# Create a logger for module 1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# Create a logger for module 2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# Configure logging settings
logging.basicConfig(
  level=logging.DEBUG,
  format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
  datefmt='%y-%m-%d %H:%M:%S'
)

# %%
# Log message with different loggers
logger1.debug("This is a debug message for module 1")
logger2.warning("This is a warning message for module 2")
logger2.debug("Debug message for module 2")
# Out:
# 26-03-23 16:17:13-module1-DEBUG-This is a debug message for module 1
# 26-03-23 16:17:13-module2-WARNING-This is a warning message for module 2
