# %% [markdown]
# Box Plot Technique to handle outliers

# %%
import numpy as np

# %%
lst_marks = [87, 92, 75, 64, 100, 58, 81, 73, 95, 69, 88, 77, 84, 91, 60, 79, 82]

minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.00])

minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(58.0),
#  np.float64(73.0),
#  np.float64(81.0),
#  np.float64(88.0),
#  np.float64(100.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 15.0

# %%
lower_fence = Q1 - 1.5*(IQR)

higher_fence = Q3 + 1.5*(IQR)

lower_fence, higher_fence
# Out:
# (np.float64(50.5), np.float64(110.5))

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
